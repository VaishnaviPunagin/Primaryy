# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviPunagin/Primaryy/blob/master/CNN%2BHSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from PIL import Image
import cv2
import keras
from keras.applications.vgg16 import preprocess_input,VGG16
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import MaxPooling2D,Conv2D,Dense,BatchNormalization,Dropout,GlobalAveragePooling2D,Flatten,Input
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from sklearn.metrics import classification_report
from keras.utils.vis_utils import plot_model
import warnings
warnings.filterwarnings('ignore')

# %%
# Function to load images

def convert_image_to_dataset(file_location):
    label=0
    df=pd.DataFrame()
    for category in glob(file_location+'/*'):
        for file in tqdm(glob(category+'/*')):
            img_array=cv2.imread(file)
            img_array=cv2.resize(img_array,(224, 224))
            data=pd.DataFrame({'image':[img_array],'label':[label]})
            df=df.append(data)
        label+=1
    return df.sample(frac=1).reset_index(drop=True)

# %%
# Function to convert output labels to its class of tumor.


def inverse_classes(num):
    if num==0:
        return 'Glioma Tumor'
    elif num==1:
        return 'Meningioma Tumor'
    elif num==2:
        return 'No Tumor'
    else:
        return 'Pituitary Tumor'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_data=convert_image_to_dataset('/content/drive/MyDrive/BrainTumor/HSV/Training')
train_x=np.array(train_data.image.to_list())
# Out:
# 100%|██████████| 395/395 [00:07<00:00, 49.46it/s]
# 100%|██████████| 826/826 [00:20<00:00, 39.98it/s]
# 100%|██████████| 822/822 [00:20<00:00, 40.86it/s]
# 100%|██████████| 827/827 [00:21<00:00, 37.74it/s]

# %%
test_data=convert_image_to_dataset('/content/drive/MyDrive/BrainTumor/HSV/Testing')
test_x=np.array(test_data.image.to_list())
# Out:
# 100%|██████████| 105/105 [00:02<00:00, 36.69it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.90it/s]
# 100%|██████████| 74/74 [00:56<00:00,  1.31it/s]
# 100%|██████████| 115/115 [00:02<00:00, 40.01it/s]

# %% [markdown]
# #Visualizing the Dataset

# %%
plt.pie(train_data.label.value_counts(),startangle=90,explode=[0.1,0.1,0.1,0.2],autopct='%0.2f%%',
        labels=['Meningioma_tumor', 'Pituitary Tumor', 'No Tumor', 'Glioma Tumor'],radius=3)
plt.show()

# %%
plt.figure(figsize=(20,15))
for i in range(12):
    plt.subplot(4,3,(i%12)+1)
    index=np.random.randint(2000)
    plt.title('This image is of {0}'.format(inverse_classes(train_data.label[index])),fontdict={'size':20,'weight':'bold'})
    plt.imshow(train_data.image[index])
    plt.tight_layout()

# %% [markdown]
# #Callback Functions

# %%
early_stop=EarlyStopping(patience=3)
reduceLR=ReduceLROnPlateau(patience=2)

# %%
# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.32.128.34:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.32.128.34:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# #CNN Approach

# %%
# instantiating the model in the strategy scope creates the model on the TPU

with tpu_strategy.scope():
    model_cnn=Sequential()
    model_cnn.add(Input(shape=(224,224,3)))
    model_cnn.add(Conv2D(128,(3,3)))
    model_cnn.add(MaxPooling2D((2,2)))
    model_cnn.add(BatchNormalization())
    model_cnn.add(Conv2D(64,(3,3)))
    model_cnn.add(MaxPooling2D((2,2)))
    model_cnn.add(BatchNormalization())
    model_cnn.add(Conv2D(32,(3,3)))
    model_cnn.add(MaxPooling2D((2,2)))
    model_cnn.add(BatchNormalization())
    model_cnn.add(Flatten())
    model_cnn.add(Dense(128,activation='relu'))
    model_cnn.add(Dropout(0.2))
    model_cnn.add(Dense(64,activation='relu'))
    model_cnn.add(Dense(4,activation='softmax'))
    model_cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
plot_model(model_cnn)

# %%
r1=model_cnn.fit(train_x,train_data.label,validation_split=0.1,epochs=20,callbacks=[reduceLR])
# Out:
# Epoch 1/20
# 81/81 [==============================] - 20s 144ms/step - loss: 1.3451 - accuracy: 0.5180 - val_loss: 4.0343 - val_accuracy: 0.4321 - lr: 0.0010
# Epoch 2/20
# 81/81 [==============================] - 3s 39ms/step - loss: 0.9048 - accuracy: 0.6392 - val_loss: 5.0518 - val_accuracy: 0.5470 - lr: 0.0010
# Epoch 3/20
# 81/81 [==============================] - 4s 50ms/step - loss: 0.7348 - accuracy: 0.6926 - val_loss: 0.8663 - val_accuracy: 0.6725 - lr: 0.0010
# Epoch 4/20
# 81/81 [==============================] - 3s 40ms/step - loss: 0.5709 - accuracy: 0.7530 - val_loss: 0.8695 - val_accuracy: 0.6864 - lr: 0.0010
# Epoch 5/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.4789 - accuracy: 0.8072 - val_loss: 0.5772 - val_accuracy: 0.7735 - lr: 0.0010
# Epoch 6/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.3452 - accuracy: 0.8606 - val_loss: 0.7455 - val_accuracy: 0.7875 - lr: 0.0010
# Epoch 7/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.2997 - accuracy: 0.8823 - val_loss: 0.5232 - val_accuracy: 0.8502 - lr: 0.0010
# Epoch 8/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.2458 - accuracy: 0.9036 - val_loss: 0.7459 - val_accuracy: 0.7770 - lr: 0.0010
# Epoch 9/20
# 81/81 [==============================] - 3s 42ms/step - loss: 0.1998 - accuracy: 0.9253 - val_loss: 0.6681 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 10/20
# 81/81 [==============================] - 3s 42ms/step - loss: 0.1371 - accuracy: 0.9450 - val_loss: 0.5110 - val_accuracy: 0.8746 - lr: 1.0000e-04
# Epoch 11/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.1029 - accuracy: 0.9605 - val_loss: 0.4638 - val_accuracy: 0.8920 - lr: 1.0000e-04
# Epoch 12/20
# 81/81 [==============================] - 3s 43ms/step - loss: 0.1052 - accuracy: 0.9648 - val_loss: 0.4659 - val_accuracy: 0.8920 - lr: 1.0000e-04
# Epoch 13/20
# 81/81 [==============================] - 3s 40ms/step - loss: 0.0952 - accuracy: 0.9675 - val_loss: 0.4547 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 14/20
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0746 - accuracy: 0.9764 - val_loss: 0.4628 - val_accuracy: 0.8955 - lr: 1.0000e-04
# Epoch 15/20
# 81/81 [==============================] - 3s 42ms/step - loss: 0.0696 - accuracy: 0.9783 - val_loss: 0.4458 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 16/20
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0693 - accuracy: 0.9756 - val_loss: 0.4704 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 17/20
# 81/81 [==============================] - 4s 43ms/step - loss: 0.0630 - accuracy: 0.9806 - val_loss: 0.4379 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 18/20
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0601 - accuracy: 0.9803 - val_loss: 0.4395 - val_accuracy: 0.9094 - lr: 1.0000e-04
# Epoch 19/20
# 81/81 [==============================] - 3s 41ms/step - loss: 0.0608 - accuracy: 0.9768 - val_loss: 0.4317 - val_accuracy: 0.9059 - lr: 1.0000e-04
# Epoch 20/20
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0464 - accuracy: 0.9857 - val_loss: 0.4562 - val_accuracy: 0.9129 - lr: 1.0000e-04
